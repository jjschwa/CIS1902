# %%
# TODO: ADD IMPORTS HERE AS NEEDED

# DO NOT CHANGE THIS LINE (make sure you import numpy as np)
np.random.seed(0)

# %% [markdown]
# # Part 0: Numpy Practice

# %% [markdown]
# Here's a convenient link to the Numpy documentation: https://numpy.org/doc/stable/reference/arrays.ndarray.html#
#
# Hint: you might want to check out this page https://numpy.org/doc/stable/reference/random/generated/numpy.random.randint.html#numpy.random.randint

# %% [markdown]
# ### Step 1
#
# Create an `np array` called `scores` that stores the scores for 5 students' miderm1, midterm2, and final exams
#
# The scores should be randomized between `65` and `100` inclusive.
#
# The array columns and rows should NOT be labeled (in otherwords, your array should only consist of integers)
#
# hint: don't forget your import(s) at the top of the notebook

# %%
scores = None

# %% [markdown]
# ### Step 2 - Basic Array Info
#
# Print:
# - the shape of the array
# - number of dimensions
# - total number of elements
#
# Please make sure all 3 of those are displayed when the cell is run

# %% [markdown]
# ### Step 3 - Vectorized Computation
# - Compute the average score for each student (row average) without loops.
# - Compute the average score for each exam (column average).
#
# Display both of these results.

# %%
# Compute the average score for each student (row average) without loops.

avg_score_student = 0

# Compute the average score for each exam (column average).

avg_score_exam = 0

# Display the results

# %% [markdown]
# ### Step 4 - Broadcasting
#
# A curve adds +5 points to every exam score
#
# Use broadcasting to create a new curved array
#
# Then cap all scores at 100 after curving
#
# Display the final array

# %%
curved_scores = None

# Display the array

# %% [markdown]
# ### Step 5 - Analysis
# Find:
#
# - the student with the highest average (hint: https://numpy.org/doc/stable/reference/generated/numpy.ndarray.argmax.html)
#
# - the exam with the lowest average
#
# And display them both
#
# -------
#
# Then:
#
# - Create a boolean array showing which scores are ≥ 90

# %%
# the student with the highest average

# the exam with the lowest average

# %%
# Create a boolean array showing which scores are ≥ 90.

# %% [markdown]
# # Let's switch gears into Pandas!
#
# hint: don't forget your import(s) at the top of the notebook
#
# Here's a convenient link to the Pandas documentation: https://pandas.pydata.org/docs/reference/frame.html
#
# Though, often googling can get you there too.
#
# # Part 1: Cleaning
# 1. Read the CSV `nyc-property-sales.csv` as a pandas dataframe
# 2. convert the following columns into numeric values:
# - residential_units
# - commercial_units
# - total_units
# - land_square_feet
# - gross_square_feet
# - year_built
# - sale_price
#
# 3. only include rows that have the `building_class_category`:
# - 01 ONE FAMILY DWELLINGS
# - 02 TWO FAMILY DWELLINGS
# - 03 THREE FAMILY DWELLINGS
#
# 4. filter our data to remove:
# - rows with `residential_units` equal to 0
# - rows with no `sale_price` or with a price less than $65,000
# - rows with no `gross_square_feet` or `land_square_feet`
# - rows where `gross_square_feet` or `land_square_feet` is 0

# %%
# 1. Read csv
# 2. convert columns to numeric values
# 3. only include rows that have the `building_class_category`
# 4. filter data

# %% [markdown]
# You should now have a dataset that has no null values and 24416 rows! We highly encourage you to create a new cell and check that there are no null values in your dataframe.

# %% [markdown]
# # Part 2: Correlation between borough and property price
#
# 1. Is there a correlation between borough and property price? Based on your results, write 1-2 sentences explaining whether borough appears to influence price.
# 2. What's the average property sale price within each borough?
# 3. What's the standard deviation?

# %%
# calculations here


# do the calculations then set these variables!

correlation = " "
avg_price = 0
std_dev = 0

# print out the variables in a human readable, clear manner

# %% [markdown]
# 4. What if we consider the per sqft price? Does that change anything?

# %%
# calculations here


# do the calculations then set these variables!

sqft_avg_price = 0
sqft_std_dev = 0

# print out the variables in a human readable, clear manner

# %% [markdown]
# # Part 3: Correlation between neighborhood and property price
#
# 1. Is there a correlation between neighborhood and property price? Based on your results, write 1-2 sentences explaining whether neighborhood appears to influence price.
# 2. For each borough, which neighborhood has the most and least expensive buildings on average?
# 3. What are the average prices for those neighborhoods?

# %%
# calculations here


# do the calculations then set these variables!

correlation = " "
# set a dataframe comparing boroughs to the most and least expensive buildings on average
borough_neighborhoods = pd.DataFrame()
std_dev = 0

# print out the variables in a human readable, clear manner

# %% [markdown]
# # Part 4: Considering the average per unit price
#
# 1. What if we consider the average per unit price? Does that change anything?
# 2. For each borough, which neighborhood has the most and least expensive units on average?
# 3. What are the average unit prices for those neighborhoods?

# %%
# calculations here


# do the calculations then set these variables!

change = ""
# set a dataframe comparing boroughs to the most and least expensive buildings on average
unit_price_borough_neighborhoods = pd.DataFrame()
avg_unit_prices = 0

# print out the variables in a human readable, clear manner
